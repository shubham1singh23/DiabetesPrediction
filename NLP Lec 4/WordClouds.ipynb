# %%
import pandas as pd
from matplotlib.pyplot import inferno

data=pd.read_csv("Code_6.csv")
text=" ".join(data["fruit"])
print(text)
# Out:
# apple banana apple mango apple banana apple mango orange banana

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt

wc=WordCloud(
    width=500,
    height=300,
    colormap="inferno",
    background_color="white"
).generate(text)

plt.figure(figsize=(10,5))
plt.imshow(wc)
plt.axis("off")
plt.savefig("fruits.pdf")
plt.show()
