# %%
import pandas as pd

data=pd.read_csv("Code_0.csv")
print(data)
# Out:
#                                                    Text Language
# 0     Nature er et britisk multidisciplinÃ¦rt videns...   Danish
# 1     [1] Det er rangeret som verdens mest citerede ...   Danish
# 2     [2][3] Det er et af de fÃ¥ tilbagevÃ¦rende aka...   Danish
# 3     [3][4] Tidsskriftets primÃ¦re mÃ¥lgruppe er fo...   Danish
# 4     I starten af hvert tidsskrift er ledere, nyhed...   Danish
# ...                                                 ...      ...
# 7244  hatan ne oldu o gÃ¼nden itibaren sana gÃ¼zel b...  Turkish
# 7245  narcisa ilk baÅŸta mÃ¼cadele ettiÄŸi yollarÄ±n...  Turkish
# 7246  NasÄ±l' narsisizm artÄ±k marian onlara hem ola...  Turkish
# 7247  ArtÄ±k altÄ±n ekmek istemeyeceÄŸini mi tahmin ...  Turkish
# 7248  terry sen aslÄ±nda o meleÄŸe biraz benziyorsun...  Turkish
#
# [7249 rows x 2 columns]

# %%
import re

def clean_function(text):
    text = re.sub(r'<[^>]+>', ' ', text)             # Remove HTML tags
    text = re.sub(r'http\S+|www\S+|@\S+', ' ', text) # Remove URLs and emails
    text = re.sub(r'\d+', ' ', text)                 # Remove numbers
    text = re.sub(r'\s+', ' ', text).strip()         # Normalize spaces
    return text

data["clean_text"]=data["Text"].apply(clean_function)
print(data["clean_text"])
# Out:
# 0       Nature er et britisk multidisciplinÃ¦rt videns...
# 1       [ ] Det er rangeret som verdens mest citerede ...
# 2       [ ][ ] Det er et af de fÃ¥ tilbagevÃ¦rende aka...
# 3       [ ][ ] Tidsskriftets primÃ¦re mÃ¥lgruppe er fo...
# 4       I starten af hvert tidsskrift er ledere, nyhed...
#                               ...
# 7244    hatan ne oldu o gÃ¼nden itibaren sana gÃ¼zel b...
# 7245    narcisa ilk baÅŸta mÃ¼cadele ettiÄŸi yollarÄ±n...
# 7246    NasÄ±l' narsisizm artÄ±k marian onlara hem ola...
# 7247    ArtÄ±k altÄ±n ekmek istemeyeceÄŸini mi tahmin ...
# 7248    terry sen aslÄ±nda o meleÄŸe biraz benziyorsun...
# Name: clean_text, Length: 7249, dtype: object

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report
cv=CountVectorizer()
vector=cv.fit_transform(data["clean_text"])

features=pd.DataFrame(vector.toarray(),columns=cv.get_feature_names_out())
target=data["Language"]

x_train,x_test,y_train,y_test=train_test_split(features.values,target)

model=MultinomialNB()
model.fit(x_train,y_train)

cr=classification_report(y_test,model.predict(x_test))
print(cr)
# Out:
#               precision    recall  f1-score   support
#
#       Danish       1.00      0.94      0.97       103
#        Dutch       1.00      0.95      0.97       121
#      English       0.94      0.99      0.97       346
#       French       0.98      0.99      0.98       250
#       German       1.00      0.97      0.99       115
#      Italian       0.99      0.98      0.99       166
#   Portugeese       1.00      0.99      0.99       207
#      Spanish       0.98      1.00      0.99       212
#     Sweedish       0.96      0.98      0.97       163
#      Turkish       1.00      0.93      0.96       130
#
#     accuracy                           0.98      1813
#    macro avg       0.98      0.97      0.98      1813
# weighted avg       0.98      0.98      0.98      1813

# %%
from pickle import dump

f=open("LangModel.pkl","wb")
dump(model,f)
f.close()

f=open("Countvector.pkl","wb")
dump(cv,f)
f.close()

print("done")
# Out:
# done
