# %%
from pickle import load

f=open("Countvector2.pkl","rb")
cv=load(f)
f.close()

f=open("NewsModel.pkl","rb")
model=load(f)
f.close()

# %%
import re


text=input("Enter text")
vector_text=cv.transform([text])

result=model.predict(vector_text)
print(result)
# Out:
# ['FAKE']
