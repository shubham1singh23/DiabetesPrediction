# %%
import pandas as pd

data=pd.read_csv("Code_5.csv")

# %%
from nltk.sentiment.vader import SentimentIntensityAnalyzer

sia=SentimentIntensityAnalyzer()

def getSentiment(text):
    ps=sia.polarity_scores(text)
    if ps["compound"]<=0.05:
        return "Positive"
    elif ps["compound"]<=-0.05 :
        return "Negative"
    else:
        return "Neutral"

data["Sentiment"]=data["review"].apply(getSentiment)
print(data)
# Out:
#                            review Sentiment
# 0        nice hotel good deal !!!   Neutral
# 1              ok nothing special  Positive
# 2      great stay, wonderful time   Neutral
# 3   quality hotel excellent staff   Neutral
# 4                   poor staff :(  Positive
# 5       horrible customer service  Positive
# 6     great hotel, terrible staff   Neutral
# 7             bad air conditioner  Positive
# 8         awesome hotel not ok :(   Neutral
# 9         reasonably priced hotel  Positive
# 10   hotel, nopes its hospital :<  Positive
